# %% [markdown]
# <a href="https://colab.research.google.com/github/anitakumar/ml/blob/main/mlops_azure_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azureml-core

# %%
# !pip install azureml-opendatasets
# Out:
# ...
#   Using cached pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Using cached fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached applicationinsights-0.11.10-py2.py3-none-any.whl.metadata (982 bytes)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 77.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 92.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 13.1 MB/s eta 0:00:00
# ...

# %%
from azureml.opendatasets import PublicHolidays

# %%
from datetime import datetime
from dateutil import parser
from dateutil.relativedelta import relativedelta

# %%
today= datetime.today()

# %%
today
# Out:
# datetime.datetime(2024, 12, 27, 15, 12, 44, 766221)

# %%
lastyear= today - relativedelta(years=1)

hol = PublicHolidays(start_date=lastyear, end_date=today)

# %%
hol_df= hol.to_pandas_dataframe()
# Out:
# {'infer_column_types': 'False', 'activity': 'download'}
# {'infer_column_types': 'False', 'activity': 'download', 'activityApp': 'FileDataset'}
# [Info] read from /tmp/tmpk5tma2ze/https%3A/%2Fazureopendatastorage.azurefd.net/holidaydatacontainer/Processed/part-00000-tid-8468414522853579044-35925ba8-a227-4b80-9c89-17065e7bf1db-649-c000.snappy.parquet

# %%
hol_df.describe(datetime_is_numeric=True)
# Out:
#                                 date
# count                            547
# mean   2024-06-24 10:58:08.117001728
# min              2023-12-31 00:00:00
# 25%              2024-03-29 00:00:00
# 50%              2024-05-25 00:00:00
# 75%              2024-10-14 00:00:00
# max              2024-12-27 00:00:00

# %%
from azureml.opendatasets import Diabetes
diabetes = Diabetes.get_tabular_dataset()
db_dbts= diabetes.to_pandas_dataframe()
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}

# %%
db_dbts.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
db_dbts.query("BMI < 20")
# Out:
#      AGE  SEX   BMI    BP   S1     S2    S3    S4      S5   S6    Y
# 10    22    1  18.6  97.0  114   57.6  46.0  2.00  3.9512   83  101
# 26    19    1  19.2  87.0  124   54.0  57.0  2.00  4.1744   90  137
# 47    27    1  19.6  78.0  128   68.0  43.0  3.00  4.4427   71  142
# 70    48    1  19.9  91.0  189  109.6  69.0  3.00  3.9512  101   48
# 86    29    2  19.4  83.0  152  105.8  39.0  4.00  3.5835   83   55
# 106   22    1  19.3  82.0  156   93.2  52.0  3.00  3.9890   71  134
# 131   22    1  19.9  75.0  175  108.6  54.0  3.00  4.1271   72  158
# 136   23    1  18.8  78.0  145   72.0  63.0  2.00  3.9120   86   85
# 173   31    2  19.0  93.0  137   73.0  47.0  3.00  4.4427   78  101
# 213   49    1  19.8  88.0  188  114.8  57.0  3.00  4.3944   93   49
# 247   26    1  18.8  83.0  191  103.6  69.0  3.00  4.5218   69   51
# 263   28    2  19.2  81.0  155   94.6  51.0  3.00  3.8501   87  116
# 281   23    2  18.0  78.0  171   96.0  48.0  4.00  4.9053   92   94
# ...
