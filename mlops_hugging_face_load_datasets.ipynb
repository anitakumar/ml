# %% [markdown]
# <a href="https://colab.research.google.com/github/anitakumar/ml/blob/main/mlops_hugging_face_load_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Using Hugging face datasets, stored externally and you dont need to worry about storage
#
# The datasets can be found on this link https://huggingface.co/datasets

# %%
# !pip install datasets

# %%
# !pip install transformers

# %%
#Show all datasets in huggingface
from datasets import load_dataset # updated the import to load_dataset
# datasets_list = list_datasets()

# Accessing the dataset list is done differently as per the documentation.
# Below line is to load a dataset. This example loads a 'glue' dataset, sst2 task:
dataset = load_dataset('glue', 'sst2')

# Check the keys (features) of the dataset
print(dataset.keys())
# Out:
# dict_keys(['train', 'validation', 'test'])

# %% [markdown]
# Load datasets

# %%
movie_rationales = load_dataset('movie_rationales')
# Out:
# README.md:   0%|          | 0.00/6.65k [00:00<?, ?B/s]
# movie_rationales.py:   0%|          | 0.00/4.42k [00:00<?, ?B/s]
# The repository for movie_rationales contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/movie_rationales.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ...
# Generating test split:   0%|          | 0/199 [00:00<?, ? examples/s]

# %%
movie_rationales  # gives a preview of the datasets and the output is in json
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 1600
#     })
#     validation: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 200
#     })
#     test: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 199
#     })
# })

# %%
#select the train dataset and then port it to pandas
df_train = movie_rationales['train'].to_pandas()

# %%
df_train.head()
# Out:
#                                               review  label  \
# 0  plot : two teen couples go to a church party ,...      0
# 1  the happy bastard 's quick movie review damn\n...      0
# 2  it is movies like these that make a jaded movi...      0
# 3  " quest for camelot " is warner bros . '\nfirs...      0
# 4  synopsis : a mentally unstable man undergoing ...      0
#
#                                            evidences
# 0  [mind - fuck movie, the sad part is, downshift...
# 1  [it 's pretty much a sunken ship, sutherland i...
# 2  [the characters and acting is nothing spectacu...
# 3  [dead on arrival, the characters stink, subpar...
# 4  [it is highly derivative and somewhat boring, ...

# %%
df_train.describe()
# Out:
#              label
# count  1600.000000
# mean      0.500000
# std       0.500156
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
